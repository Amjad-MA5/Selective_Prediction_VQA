# %%
from get_predictions import *
import torch

# %% [markdown]
# ### **Load ViLT Model fined tuned on VQAv2 dataset**

# %%
model, processor = get_model()
device = 'cuda' if torch.cuda.is_available() else 'cpu'
model.to(device)
model.eval()
# Out:
# ViltForQuestionAnswering(
#   (vilt): ViltModel(
#     (embeddings): ViltEmbeddings(
#       (text_embeddings): TextEmbeddings(
#         (word_embeddings): Embedding(30522, 768)
#         (position_embeddings): Embedding(40, 768)
#         (token_type_embeddings): Embedding(2, 768)
#         (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#       )
#       (patch_embeddings): ViltPatchEmbeddings(
#         (projection): Conv2d(3, 768, kernel_size=(32, 32), stride=(32, 32))
#       )
#       (token_type_embeddings): Embedding(2, 768)
#       (dropout): Dropout(p=0.0, inplace=False)
#     )
#     (encoder): ViltEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x ViltLayer(
#           (attention): ViltAttention(
#             (attention): ViltSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#             (output): ViltSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (intermediate): ViltIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ViltOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#           (layernorm_before): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (layernorm_after): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#       )
#     )
#     (layernorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#     (pooler): ViltPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=768, out_features=1536, bias=True)
#     (1): LayerNorm((1536,), eps=1e-05, elementwise_affine=True)
#     (2): GELU(approximate='none')
#     (3): Linear(in_features=1536, out_features=3129, bias=True)
#   )
# )

# %% [markdown]
# ### **Load Validation set from VQAv2 dataset**

# %%
import sys
sys.path.append("/teamspace/studios/this_studio/Selective_Prediction_VQA")
from dataset.get_VQAv2_dataset import get_VQAv2_dataset
dataset = get_VQAv2_dataset()
validation_dataset = dataset['validation']
# Out:
# /teamspace/studios/this_studio/Selective_Prediction_VQA/dataset/data/VQAv2c.hf
# Loading from local path /teamspace/studios/this_studio/Selective_Prediction_VQA/dataset/data/VQAv2c.hf.
# Loading dataset from disk:   0%|          | 0/68 [00:00<?, ?it/s]
# Loading dataset from disk:   0%|          | 0/34 [00:00<?, ?it/s]
# Loading dataset from disk:   0%|          | 0/141 [00:00<?, ?it/s]

# %%
prediction(model, processor, validation_dataset, device)
# Out:
# Saved data for batch no: 0
# Saved data for batch no: 1
# Saved data for batch no: 2
# Saved data for batch no: 3
# Saved data for batch no: 4
# Saved data for batch no: 5
# Saved data for batch no: 6
# Saved data for batch no: 7
# Saved data for batch no: 8
# Saved data for batch no: 9
# Saved data for batch no: 10
# Saved data for batch no: 11
# Saved data for batch no: 12
# Saved data for batch no: 13
# Saved data for batch no: 14
# Saved data for batch no: 15
# Saved data for batch no: 16
# Saved data for batch no: 17
# Saved data for batch no: 18
# Saved data for batch no: 19
# Saved data for batch no: 20
# Saved data for batch no: 21
# Saved data for batch no: 22
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Saved data for batch no: 23
# Saved data for batch no: 24
# Saved data for batch no: 25
# Saved data for batch no: 26
# Saved data for batch no: 27
# Saved data for batch no: 28
# Saved data for batch no: 29
# Saved data for batch no: 30
# Saved data for batch no: 31
# Saved data for batch no: 32
# Saved data for batch no: 33
# Saved data for batch no: 34
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Saved data for batch no: 35
# Saved data for batch no: 36
# Saved data for batch no: 37
# Saved data for batch no: 38
# Saved data for batch no: 39
# Saved data for batch no: 40
# Saved data for batch no: 41
# Saved data for batch no: 42
# Saved data for batch no: 43
# Saved data for batch no: 44
# Saved data for batch no: 45
# Saved data for batch no: 46
# Saved data for batch no: 47
# Saved data for batch no: 48
# Saved data for batch no: 49
# Saved data for batch no: 50
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Saved data for batch no: 51
# Saved data for batch no: 52
# Saved data for batch no: 53
# Saved data for batch no: 54
# Saved data for batch no: 55
# Saved data for batch no: 56
# Saved data for batch no: 57
# Saved data for batch no: 58
# Saved data for batch no: 59
# Saved data for batch no: 60
# Saved data for batch no: 61
# Saved data for batch no: 62
# Saved data for batch no: 63
# Saved data for batch no: 64
# Saved data for batch no: 65
# Saved data for batch no: 66
# Saved data for batch no: 67
# Saved data for batch no: 68
# Saved data for batch no: 69
# Saved data for batch no: 70
# Saved data for batch no: 71
# Saved data for batch no: 72
# Saved data for batch no: 73
# Saved data for batch no: 74
# Saved data for batch no: 75
# Saved data for batch no: 76
# Saved data for batch no: 77
# Saved data for batch no: 78
# Saved data for batch no: 79
# Saved data for batch no: 80
# Saved data for batch no: 81
# Saved data for batch no: 82
# Saved data for batch no: 83
# Saved data for batch no: 84
# Saved data for batch no: 85
# Saved data for batch no: 86
# Saved data for batch no: 87
# Saved data for batch no: 88
# Saved data for batch no: 89
# Saved data for batch no: 90
# Saved data for batch no: 91
# Saved data for batch no: 92
# Saved data for batch no: 93
# Saved data for batch no: 94
# Saved data for batch no: 95
# Saved data for batch no: 96
# Saved data for batch no: 97
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Saved data for batch no: 98
# Saved data for batch no: 99
# Saved data for batch no: 100
# Saved data for batch no: 101
# Saved data for batch no: 102
# Saved data for batch no: 103
# Saved data for batch no: 104
# Saved data for batch no: 105
# Saved data for batch no: 106
# Saved data for batch no: 107
# Saved data for batch no: 108
# Saved data for batch no: 109
# Saved data for batch no: 110
# Saved data for batch no: 111
# Saved data for batch no: 112
# Saved data for batch no: 113
# Saved data for batch no: 114
# Saved data for batch no: 115
# Saved data for batch no: 116
# Saved data for batch no: 117
# Saved data for batch no: 118
# Saved data for batch no: 119
# Saved data for batch no: 120
# Saved data for batch no: 121
# Saved data for batch no: 122
# Saved data for batch no: 123
# Saved data for batch no: 124
# Saved data for batch no: 125
# Saved data for batch no: 126
# Saved data for batch no: 127
# Saved data for batch no: 128
# Saved data for batch no: 129
# Saved data for batch no: 130
# Saved data for batch no: 131
# Saved data for batch no: 132
# Saved data for batch no: 133
# Saved data for batch no: 134
# Saved data for batch no: 135
# Saved data for batch no: 136
# Saved data for batch no: 137
# Saved data for batch no: 138
# Saved data for batch no: 139
# Saved data for batch no: 140
# Saved data for batch no: 141
# Saved data for batch no: 142
# Saved data for batch no: 143
# Saved data for batch no: 144
# Saved data for batch no: 145
# Saved data for batch no: 146
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Saved data for batch no: 147
# Saved data for batch no: 148
# Saved data for batch no: 149
# Saved data for batch no: 150
# Saved data for batch no: 151
# Saved data for batch no: 152
# Saved data for batch no: 153
# Saved data for batch no: 154
# Saved data for batch no: 155
# Saved data for batch no: 156
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Saved data for batch no: 157
# Saved data for batch no: 158
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Saved data for batch no: 159
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Saved data for batch no: 160
# Saved data for batch no: 161
# Saved data for batch no: 162
# Saved data for batch no: 163
# Saved data for batch no: 164
# Saved data for batch no: 165
# Saved data for batch no: 166
# Saved data for batch no: 167
# Saved data for batch no: 168
# Saved data for batch no: 169
# Saved data for batch no: 170
# Saved data for batch no: 171
# Saved data for batch no: 172
# Saved data for batch no: 173
# Saved data for batch no: 174
# Saved data for batch no: 175
# Saved data for batch no: 176
# Saved data for batch no: 177
# Saved data for batch no: 178
# Saved data for batch no: 179
# Saved data for batch no: 180
# Saved data for batch no: 181
# Saved data for batch no: 182
# Saved data for batch no: 183
# Saved data for batch no: 184
# Saved data for batch no: 185
# Saved data for batch no: 186
# Saved data for batch no: 187
# Saved data for batch no: 188
# Saved data for batch no: 189
# Saved data for batch no: 190
# Saved data for batch no: 191
# Saved data for batch no: 192
# Saved data for batch no: 193
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Saved data for batch no: 194
# Saved data for batch no: 195
# Saved data for batch no: 196
# Saved data for batch no: 197
# Saved data for batch no: 198
# Saved data for batch no: 199
# Saved data for batch no: 200
# Saved data for batch no: 201
# Saved data for batch no: 202
# Saved data for batch no: 203
# Saved data for batch no: 204
# Saved data for batch no: 205
# Saved data for batch no: 206
# Saved data for batch no: 207
# Saved data for batch no: 208
# Saved data for batch no: 209
# Saved data for batch no: 210
# Saved data for batch no: 211
# Saved data for batch no: 212
# Saved data for batch no: 213
# Saved data for batch no: 214
# Saved data for batch no: 215
# Saved data for batch no: 216
# Saved data for batch no: 217
# Saved data for batch no: 218
# Saved data for batch no: 219
# Saved data for batch no: 220
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Saved data for batch no: 221
# Saved data for batch no: 222
# Saved data for batch no: 223
# Saved data for batch no: 224
# Saved data for batch no: 225
# Saved data for batch no: 226
# Saved data for batch no: 227
# Saved data for batch no: 228
# Saved data for batch no: 229
# Saved data for batch no: 230
# Saved data for batch no: 231
# Saved data for batch no: 232
# Saved data for batch no: 233
# Saved data for batch no: 234
# Saved data for batch no: 235
# Saved data for batch no: 236
# Saved data for batch no: 237
# Saved data for batch no: 238
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Saved data for batch no: 239
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Saved data for batch no: 240
# Saved data for batch no: 241
# Saved data for batch no: 242
# Saved data for batch no: 243
# Saved data for batch no: 244
# Saved data for batch no: 245
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Saved data for batch no: 246
# Saved data for batch no: 247
# Saved data for batch no: 248
# Saved data for batch no: 249
# Saved data for batch no: 250
# Saved data for batch no: 251
# Saved data for batch no: 252
# Saved data for batch no: 253
# Saved data for batch no: 254
# Saved data for batch no: 255
# Saved data for batch no: 256
# Saved data for batch no: 257
# Saved data for batch no: 258
# Saved data for batch no: 259
# Saved data for batch no: 260
# Saved data for batch no: 261
# Saved data for batch no: 262
# Saved data for batch no: 263
# Saved data for batch no: 264
# Saved data for batch no: 265
# Saved data for batch no: 266
# Saved data for batch no: 267
# Saved data for batch no: 268
# Saved data for batch no: 269
# Saved data for batch no: 270
# Saved data for batch no: 271
# Saved data for batch no: 272
# Saved data for batch no: 273
# Saved data for batch no: 274
# Saved data for batch no: 275
# Saved data for batch no: 276
# Saved data for batch no: 277
# Saved data for batch no: 278
# Saved data for batch no: 279
# Saved data for batch no: 280
# Saved data for batch no: 281
# Saved data for batch no: 282
# Saved data for batch no: 283
# Saved data for batch no: 284
# Saved data for batch no: 285
# Saved data for batch no: 286
# Saved data for batch no: 287
# Saved data for batch no: 288
# Saved data for batch no: 289
# Saved data for batch no: 290
# Saved data for batch no: 291
# Saved data for batch no: 292
# Saved data for batch no: 293
# Saved data for batch no: 294
# Saved data for batch no: 295
# Saved data for batch no: 296
# Saved data for batch no: 297
# Saved data for batch no: 298
# Saved data for batch no: 299
# Saved data for batch no: 300
# Saved data for batch no: 301
# Saved data for batch no: 302
# Saved data for batch no: 303
# Saved data for batch no: 304
# Saved data for batch no: 305
# Saved data for batch no: 306
# Saved data for batch no: 307
# Saved data for batch no: 308
# Saved data for batch no: 309
# Saved data for batch no: 310
# Saved data for batch no: 311
# Saved data for batch no: 312
# Saved data for batch no: 313
# Saved data for batch no: 314
# Saved data for batch no: 315
# Saved data for batch no: 316
# Saved data for batch no: 317
# Saved data for batch no: 318
# Saved data for batch no: 319
# Saved data for batch no: 320
# Saved data for batch no: 321
# Saved data for batch no: 322
# Saved data for batch no: 323
# Saved data for batch no: 324
# Saved data for batch no: 325
# Saved data for batch no: 326
# Saved data for batch no: 327
# Saved data for batch no: 328
# Saved data for batch no: 329
# Saved data for batch no: 330
# Saved data for batch no: 331
# Saved data for batch no: 332
# Saved data for batch no: 333
# Saved data for batch no: 334
# Saved data for batch no: 335
# Saved data for batch no: 336
# Saved data for batch no: 337
# Saved data for batch no: 338
# Saved data for batch no: 339
# Saved data for batch no: 340
# Saved data for batch no: 341
# Saved data for batch no: 342
# Saved data for batch no: 343
# Saved data for batch no: 344
# Saved data for batch no: 345
# Saved data for batch no: 346
# Saved data for batch no: 347
# Saved data for batch no: 348
# Saved data for batch no: 349
# Saved data for batch no: 350
# Saved data for batch no: 351
# Saved data for batch no: 352
# Saved data for batch no: 353
# Saved data for batch no: 354
# Saved data for batch no: 355
# Saved data for batch no: 356
# Saved data for batch no: 357
# Saved data for batch no: 358
# Saved data for batch no: 359
# Saved data for batch no: 360
# Saved data for batch no: 361
# Saved data for batch no: 362
# Saved data for batch no: 363
# Saved data for batch no: 364
# Saved data for batch no: 365
# Saved data for batch no: 366
# Saved data for batch no: 367
# Saved data for batch no: 368
# Saved data for batch no: 369
# Saved data for batch no: 370
# Saved data for batch no: 371
# Saved data for batch no: 372
# Saved data for batch no: 373
# Saved data for batch no: 374
# Saved data for batch no: 375
# Saved data for batch no: 376
# Saved data for batch no: 377
# Saved data for batch no: 378
# Saved data for batch no: 379
# Saved data for batch no: 380
# Saved data for batch no: 381
# Saved data for batch no: 382
# Saved data for batch no: 383
# Saved data for batch no: 384
# Saved data for batch no: 385
# Saved data for batch no: 386
# Saved data for batch no: 387
# Saved data for batch no: 388
# Saved data for batch no: 389
# Saved data for batch no: 390
# Saved data for batch no: 391
# Saved data for batch no: 392
# Saved data for batch no: 393
# Saved data for batch no: 394
# Saved data for batch no: 395
# Saved data for batch no: 396
# Saved data for batch no: 397
# Saved data for batch no: 398
# Saved data for batch no: 399
# Saved data for batch no: 400
# Saved data for batch no: 401
# Saved data for batch no: 402
# Saved data for batch no: 403
# Saved data for batch no: 404
# Saved data for batch no: 405
# Saved data for batch no: 406
# Saved data for batch no: 407
# Saved data for batch no: 408
# Saved data for batch no: 409
# Saved data for batch no: 410
# Saved data for batch no: 411
# Saved data for batch no: 412
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Saved data for batch no: 413
# Saved data for batch no: 414
# Saved data for batch no: 415
# Saved data for batch no: 416
# Saved data for batch no: 417
# Saved data for batch no: 418
# Saved data for batch no: 419
# Saved data for batch no: 420
# Saved data for batch no: 421
# Saved data for batch no: 422
# Saved data for batch no: 423
# Saved data for batch no: 424
# Saved data for batch no: 425
# Saved data for batch no: 426
# Saved data for batch no: 427
# Saved data for batch no: 428
# Saved data for batch no: 429
# Saved data for batch no: 430
# Saved data for batch no: 431
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Saved data for batch no: 432
# Saved data for batch no: 433
# Saved data for batch no: 434
# Saved data for batch no: 435
# Saved data for batch no: 436
# Saved data for batch no: 437
# Saved data for batch no: 438
# Saved data for batch no: 439
# Saved data for batch no: 440
# Saved data for batch no: 441
# Saved data for batch no: 442
# Saved data for batch no: 443
# Saved data for batch no: 444
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Saved data for batch no: 445
# Saved data for batch no: 446
# Saved data for batch no: 447
# Saved data for batch no: 448
# Saved data for batch no: 449
# Saved data for batch no: 450
# Saved data for batch no: 451
# Saved data for batch no: 452
# Saved data for batch no: 453
# Saved data for batch no: 454
# Saved data for batch no: 455
# Saved data for batch no: 456
# Saved data for batch no: 457
# Saved data for batch no: 458
# Saved data for batch no: 459
# Saved data for batch no: 460
# Saved data for batch no: 461
# Saved data for batch no: 462
# Saved data for batch no: 463
# Saved data for batch no: 464
# Saved data for batch no: 465
# Saved data for batch no: 466
# Saved data for batch no: 467
# Saved data for batch no: 468
# Saved data for batch no: 469
# Saved data for batch no: 470
# Saved data for batch no: 471
# Saved data for batch no: 472
# Saved data for batch no: 473
# Saved data for batch no: 474
# Saved data for batch no: 475
# Saved data for batch no: 476
# Saved data for batch no: 477
# Saved data for batch no: 478
# Saved data for batch no: 479
# Saved data for batch no: 480
# Saved data for batch no: 481
# Saved data for batch no: 482
# Saved data for batch no: 483
# Saved data for batch no: 484
# Saved data for batch no: 485
# Saved data for batch no: 486
# Saved data for batch no: 487
# Saved data for batch no: 488
# Saved data for batch no: 489
# Saved data for batch no: 490
# Saved data for batch no: 491
# Saved data for batch no: 492
# Saved data for batch no: 493
# Saved data for batch no: 494
# Saved data for batch no: 495
# Saved data for batch no: 496
# Saved data for batch no: 497
# Saved data for batch no: 498
# Saved data for batch no: 499
# Saved data for batch no: 500
# Saved data for batch no: 501
# Saved data for batch no: 502
# Saved data for batch no: 503
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Saved data for batch no: 504
# Saved data for batch no: 505
# Saved data for batch no: 506
# Saved data for batch no: 507
# Saved data for batch no: 508
# Saved data for batch no: 509
# Saved data for batch no: 510
# Saved data for batch no: 511
# Saved data for batch no: 512
# Saved data for batch no: 513
# Saved data for batch no: 514
# Saved data for batch no: 515
# Saved data for batch no: 516
# Saved data for batch no: 517
# Saved data for batch no: 518
# Saved data for batch no: 519
# Saved data for batch no: 520
# Saved data for batch no: 521
# Saved data for batch no: 522
# Saved data for batch no: 523
# Saved data for batch no: 524
# Saved data for batch no: 525
# Saved data for batch no: 526
# Saved data for batch no: 527
# Saved data for batch no: 528
# Saved data for batch no: 529
# Saved data for batch no: 530
# Saved data for batch no: 531
# Saved data for batch no: 532
# Saved data for batch no: 533
# Saved data for batch no: 534
# Saved data for batch no: 535
# Saved data for batch no: 536
# Saved data for batch no: 537
# Saved data for batch no: 538
# Saved data for batch no: 539
# Saved data for batch no: 540
# Saved data for batch no: 541
# Saved data for batch no: 542
# Saved data for batch no: 543
# Saved data for batch no: 544
# Saved data for batch no: 545
# Saved data for batch no: 546
# Saved data for batch no: 547
# Saved data for batch no: 548
# Saved data for batch no: 549
# Saved data for batch no: 550
# Saved data for batch no: 551
# Saved data for batch no: 552
# Saved data for batch no: 553
# Saved data for batch no: 554
# Saved data for batch no: 555
# Saved data for batch no: 556
# Saved data for batch no: 557
# Saved data for batch no: 558
# Saved data for batch no: 559
# Saved data for batch no: 560
# Saved data for batch no: 561
# Saved data for batch no: 562
# Saved data for batch no: 563
# Saved data for batch no: 564
# Saved data for batch no: 565
# Saved data for batch no: 566
# Saved data for batch no: 567
# Saved data for batch no: 568
# Saved data for batch no: 569
# Saved data for batch no: 570
# Saved data for batch no: 571
# Saved data for batch no: 572
# Saved data for batch no: 573
# Saved data for batch no: 574
# Saved data for batch no: 575
# Saved data for batch no: 576
# Saved data for batch no: 577
# Saved data for batch no: 578
# Saved data for batch no: 579
# Saved data for batch no: 580
# Saved data for batch no: 581
# Saved data for batch no: 582
# Saved data for batch no: 583
# Saved data for batch no: 584
# Saved data for batch no: 585
# Saved data for batch no: 586
# Saved data for batch no: 587
# Saved data for batch no: 588
# Saved data for batch no: 589
# Saved data for batch no: 590
# Saved data for batch no: 591
# Saved data for batch no: 592
# Saved data for batch no: 593
# Saved data for batch no: 594
# Saved data for batch no: 595
# Saved data for batch no: 596
# Saved data for batch no: 597
# Saved data for batch no: 598
# Saved data for batch no: 599
# Saved data for batch no: 600
# Saved data for batch no: 601
# Saved data for batch no: 602
# Saved data for batch no: 603
# Saved data for batch no: 604
# Saved data for batch no: 605
# Saved data for batch no: 606
# Saved data for batch no: 607
# Saved data for batch no: 608
# Saved data for batch no: 609
# Saved data for batch no: 610
# Saved data for batch no: 611
# Saved data for batch no: 612
# Saved data for batch no: 613
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Saved data for batch no: 614
# Saved data for batch no: 615
# Saved data for batch no: 616
# Saved data for batch no: 617
# Saved data for batch no: 618
# Saved data for batch no: 619
# Saved data for batch no: 620
# Saved data for batch no: 621
# Saved data for batch no: 622
# Saved data for batch no: 623
# Saved data for batch no: 624
# Saved data for batch no: 625
# Saved data for batch no: 626
# Saved data for batch no: 627
# Saved data for batch no: 628
# Saved data for batch no: 629
# Saved data for batch no: 630
# Saved data for batch no: 631
# Saved data for batch no: 632
# Saved data for batch no: 633
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Saved data for batch no: 634
# Saved data for batch no: 635
# Saved data for batch no: 636
# Saved data for batch no: 637
# Saved data for batch no: 638
# Saved data for batch no: 639
# Saved data for batch no: 640
# Saved data for batch no: 641
# Saved data for batch no: 642
# Saved data for batch no: 643
# Saved data for batch no: 644
# Saved data for batch no: 645
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Saved data for batch no: 646
# Saved data for batch no: 647
# Saved data for batch no: 648
# Saved data for batch no: 649
# Saved data for batch no: 650
# Saved data for batch no: 651
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Saved data for batch no: 652
# Saved data for batch no: 653
# Saved data for batch no: 654
# Saved data for batch no: 655
# Saved data for batch no: 656
# Saved data for batch no: 657
# Saved data for batch no: 658
# Saved data for batch no: 659
# Saved data for batch no: 660
# Saved data for batch no: 661
# Saved data for batch no: 662
# Saved data for batch no: 663
# Saved data for batch no: 664
# Saved data for batch no: 665
# Saved data for batch no: 666
# Saved data for batch no: 667
# Saved data for batch no: 668
# Saved data for batch no: 669
# Saved data for batch no: 670
# Saved data for batch no: 671
# Saved data for batch no: 672
# Saved data for batch no: 673
# Saved data for batch no: 674
# Saved data for batch no: 675
# Saved data for batch no: 676
# Saved data for batch no: 677
# Saved data for batch no: 678
# Saved data for batch no: 679
# Saved data for batch no: 680
# Saved data for batch no: 681
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Saved data for batch no: 682
# Saved data for batch no: 683
# Saved data for batch no: 684
# Saved data for batch no: 685
# Saved data for batch no: 686
# Saved data for batch no: 687
# Saved data for batch no: 688
# Saved data for batch no: 689
# Saved data for batch no: 690
# Saved data for batch no: 691
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Saved data for batch no: 692
# Saved data for batch no: 693
# Saved data for batch no: 694
# Saved data for batch no: 695
# Saved data for batch no: 696
# Saved data for batch no: 697
# Saved data for batch no: 698
# Saved data for batch no: 699
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Saved data for batch no: 700
# Saved data for batch no: 701
# Saved data for batch no: 702
# Saved data for batch no: 703
# Saved data for batch no: 704
# Saved data for batch no: 705
# Saved data for batch no: 706
# Saved data for batch no: 707
# Saved data for batch no: 708
# Saved data for batch no: 709
# Saved data for batch no: 710
# Saved data for batch no: 711
# Saved data for batch no: 712
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Saved data for batch no: 713
# Saved data for batch no: 714
# Saved data for batch no: 715
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Saved data for batch no: 716
# Saved data for batch no: 717
# Saved data for batch no: 718
# Saved data for batch no: 719
# Saved data for batch no: 720
# Saved data for batch no: 721
# Saved data for batch no: 722
# Saved data for batch no: 723
# Saved data for batch no: 724
# Saved data for batch no: 725
# Saved data for batch no: 726
# Saved data for batch no: 727
# Saved data for batch no: 728
# Saved data for batch no: 729
# Saved data for batch no: 730
# Saved data for batch no: 731
# Saved data for batch no: 732
# Saved data for batch no: 733
# Saved data for batch no: 734
# Saved data for batch no: 735
# Saved data for batch no: 736
# Saved data for batch no: 737
# Saved data for batch no: 738
# Saved data for batch no: 739
# Saved data for batch no: 740
# Saved data for batch no: 741
# Saved data for batch no: 742
# Saved data for batch no: 743
# Saved data for batch no: 744
# Saved data for batch no: 745
# Saved data for batch no: 746
# Saved data for batch no: 747
# Saved data for batch no: 748
# Saved data for batch no: 749
# Saved data for batch no: 750
# Saved data for batch no: 751
# Saved data for batch no: 752
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Saved data for batch no: 753
# Saved data for batch no: 754
# Saved data for batch no: 755
# Saved data for batch no: 756
# Saved data for batch no: 757
# Saved data for batch no: 758
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Saved data for batch no: 759
# Saved data for batch no: 760
# Saved data for batch no: 761
# Saved data for batch no: 762
# Saved data for batch no: 763
# Saved data for batch no: 764
# Saved data for batch no: 765
# Saved data for batch no: 766
# Saved data for batch no: 767
# Saved data for batch no: 768
# Saved data for batch no: 769
# Saved data for batch no: 770
# Saved data for batch no: 771
# Saved data for batch no: 772
# Saved data for batch no: 773
# Saved data for batch no: 774
# Saved data for batch no: 775
# Saved data for batch no: 776
# Saved data for batch no: 777
# Saved data for batch no: 778
# Saved data for batch no: 779
# Saved data for batch no: 780
# Saved data for batch no: 781
# Saved data for batch no: 782
# Saved data for batch no: 783
# Saved data for batch no: 784
# Saved data for batch no: 785
# Saved data for batch no: 786
# Saved data for batch no: 787
# Saved data for batch no: 788
# Saved data for batch no: 789
# Saved data for batch no: 790
# Saved data for batch no: 791
# Saved data for batch no: 792
# Saved data for batch no: 793
# Saved data for batch no: 794
# Saved data for batch no: 795
# Saved data for batch no: 796
# Saved data for batch no: 797
# Saved data for batch no: 798
# Saved data for batch no: 799
# Saved data for batch no: 800
# Saved data for batch no: 801
# Saved data for batch no: 802
# Saved data for batch no: 803
# Saved data for batch no: 804
# Saved data for batch no: 805
# Saved data for batch no: 806
# Saved data for batch no: 807
# Saved data for batch no: 808
# Saved data for batch no: 809
# Saved data for batch no: 810
# Saved data for batch no: 811
# Saved data for batch no: 812
# Saved data for batch no: 813
# Saved data for batch no: 814
# Saved data for batch no: 815
# Saved data for batch no: 816
# Saved data for batch no: 817
# Saved data for batch no: 818
# Saved data for batch no: 819
# Saved data for batch no: 820
# Saved data for batch no: 821
# Saved data for batch no: 822
# Saved data for batch no: 823
# Saved data for batch no: 824
# Saved data for batch no: 825
# Saved data for batch no: 826
# Saved data for batch no: 827
# Saved data for batch no: 828
# Saved data for batch no: 829
# Saved data for batch no: 830
# Saved data for batch no: 831
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Saved data for batch no: 832
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Saved data for batch no: 833
# Saved data for batch no: 834
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Saved data for batch no: 835
# Saved data for batch no: 836
# Saved data for batch no: 837
# Saved data for batch no: 838
# Saved data for batch no: 839
# Saved data for batch no: 840
# Saved data for batch no: 841
# Saved data for batch no: 842
# Saved data for batch no: 843
# Saved data for batch no: 844
# Saved data for batch no: 845
# Saved data for batch no: 846
# Saved data for batch no: 847
# Saved data for batch no: 848
# Saved data for batch no: 849
# Saved data for batch no: 850
# Saved data for batch no: 851
# Saved data for batch no: 852
# Saved data for batch no: 853
# Saved data for batch no: 854
# Saved data for batch no: 855
# Saved data for batch no: 856
# Saved data for batch no: 857
# Saved data for batch no: 858
# Saved data for batch no: 859
# Saved data for batch no: 860
# Saved data for batch no: 861
# Saved data for batch no: 862
# Saved data for batch no: 863
# Saved data for batch no: 864
# Saved data for batch no: 865
# Saved data for batch no: 866
# Saved data for batch no: 867
# Saved data for batch no: 868
# Saved data for batch no: 869
# Saved data for batch no: 870
# Saved data for batch no: 871
# Saved data for batch no: 872
# Saved data for batch no: 873
# Saved data for batch no: 874
# Saved data for batch no: 875
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Saved data for batch no: 876
# Saved data for batch no: 877
# Saved data for batch no: 878
# Saved data for batch no: 879
# Saved data for batch no: 880
# Saved data for batch no: 881
# Saved data for batch no: 882
# Saved data for batch no: 883
# Saved data for batch no: 884
# Saved data for batch no: 885
# Saved data for batch no: 886
# Saved data for batch no: 887
# Saved data for batch no: 888
# Saved data for batch no: 889
# Saved data for batch no: 890
# Saved data for batch no: 891
# Saved data for batch no: 892
# Saved data for batch no: 893
# Saved data for batch no: 894
# Saved data for batch no: 895
# Saved data for batch no: 896
# Saved data for batch no: 897
# Saved data for batch no: 898
# Saved data for batch no: 899
# Saved data for batch no: 900
# Saved data for batch no: 901
# Saved data for batch no: 902
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Saved data for batch no: 903
# Saved data for batch no: 904
# Saved data for batch no: 905
# Saved data for batch no: 906
# Saved data for batch no: 907
# Saved data for batch no: 908
# Saved data for batch no: 909
# Saved data for batch no: 910
# Saved data for batch no: 911
# Saved data for batch no: 912
# Saved data for batch no: 913
# Saved data for batch no: 914
# Saved data for batch no: 915
# Saved data for batch no: 916
# Saved data for batch no: 917
# Saved data for batch no: 918
# Saved data for batch no: 919
# Saved data for batch no: 920
# Saved data for batch no: 921
# Saved data for batch no: 922
# Saved data for batch no: 923
# Saved data for batch no: 924
# Saved data for batch no: 925
# Saved data for batch no: 926
# Saved data for batch no: 927
# Saved data for batch no: 928
# Saved data for batch no: 929
# Saved data for batch no: 930
# Saved data for batch no: 931
# Saved data for batch no: 932
# Saved data for batch no: 933
# Saved data for batch no: 934
# Saved data for batch no: 935
# Saved data for batch no: 936
# Saved data for batch no: 937
# Saved data for batch no: 938
# Saved data for batch no: 939
# Saved data for batch no: 940
# Saved data for batch no: 941
# Saved data for batch no: 942
# Saved data for batch no: 943
# Saved data for batch no: 944
# Saved data for batch no: 945
# Saved data for batch no: 946
# Saved data for batch no: 947
# Saved data for batch no: 948
# Saved data for batch no: 949
# Saved data for batch no: 950
# Saved data for batch no: 951
# Saved data for batch no: 952
# Saved data for batch no: 953
# Saved data for batch no: 954
# Saved data for batch no: 955
# Saved data for batch no: 956
# Saved data for batch no: 957
# Saved data for batch no: 958
# Saved data for batch no: 959
# Saved data for batch no: 960
# Saved data for batch no: 961
# Saved data for batch no: 962
# Saved data for batch no: 963
# Saved data for batch no: 964
# Saved data for batch no: 965
# Saved data for batch no: 966
# Saved data for batch no: 967
# Saved data for batch no: 968
# Saved data for batch no: 969
# Saved data for batch no: 970
# Saved data for batch no: 971
# Saved data for batch no: 972
# Saved data for batch no: 973
# Saved data for batch no: 974
# Saved data for batch no: 975
# Saved data for batch no: 976
# Saved data for batch no: 977
# Saved data for batch no: 978
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Saved data for batch no: 979
# Saved data for batch no: 980
# Saved data for batch no: 981
# Saved data for batch no: 982
# Saved data for batch no: 983
# Saved data for batch no: 984
# Saved data for batch no: 985
# Saved data for batch no: 986
# Saved data for batch no: 987
# Saved data for batch no: 988
# Saved data for batch no: 989
# Saved data for batch no: 990
# Saved data for batch no: 991
# Saved data for batch no: 992
# Saved data for batch no: 993
# Saved data for batch no: 994
# Saved data for batch no: 995
# Saved data for batch no: 996
# Saved data for batch no: 997
# Saved data for batch no: 998
# Saved data for batch no: 999
# Saved data for batch no: 1000
# Saved data for batch no: 1001
# Saved data for batch no: 1002
# Saved data for batch no: 1003
# Saved data for batch no: 1004
# Saved data for batch no: 1005
# Saved data for batch no: 1006
# Saved data for batch no: 1007
# Saved data for batch no: 1008
# Saved data for batch no: 1009
# Saved data for batch no: 1010
# Saved data for batch no: 1011
# Saved data for batch no: 1012
# Saved data for batch no: 1013
# Saved data for batch no: 1014
# Saved data for batch no: 1015
# Saved data for batch no: 1016
# Saved data for batch no: 1017
# Saved data for batch no: 1018
# Saved data for batch no: 1019
# Saved data for batch no: 1020
# Saved data for batch no: 1021
# Saved data for batch no: 1022
# Saved data for batch no: 1023
# Saved data for batch no: 1024
# Saved data for batch no: 1025
# Saved data for batch no: 1026
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Saved data for batch no: 1027
# Saved data for batch no: 1028
# Saved data for batch no: 1029
# Saved data for batch no: 1030
# Saved data for batch no: 1031
# Saved data for batch no: 1032
# Saved data for batch no: 1033
# Saved data for batch no: 1034
# Saved data for batch no: 1035
# Saved data for batch no: 1036
# Saved data for batch no: 1037
# Saved data for batch no: 1038
# Saved data for batch no: 1039
# Saved data for batch no: 1040
# Saved data for batch no: 1041
# Saved data for batch no: 1042
# Saved data for batch no: 1043
# Saved data for batch no: 1044
# Saved data for batch no: 1045
# Saved data for batch no: 1046
# Saved data for batch no: 1047
# Saved data for batch no: 1048
# Saved data for batch no: 1049
# Saved data for batch no: 1050
# Saved data for batch no: 1051
# Saved data for batch no: 1052
# Saved data for batch no: 1053
# Saved data for batch no: 1054
# Saved data for batch no: 1055
# Saved data for batch no: 1056
# Saved data for batch no: 1057
# Saved data for batch no: 1058
# Saved data for batch no: 1059
# Saved data for batch no: 1060
# Saved data for batch no: 1061
# Saved data for batch no: 1062
# Saved data for batch no: 1063
# Saved data for batch no: 1064
# Saved data for batch no: 1065
# Saved data for batch no: 1066
# Saved data for batch no: 1067
# Saved data for batch no: 1068
# Saved data for batch no: 1069
# Saved data for batch no: 1070
# Saved data for batch no: 1071
# Saved data for batch no: 1072
# Saved data for batch no: 1073
# Saved data for batch no: 1074
# Saved data for batch no: 1075
# Saved data for batch no: 1076
# Saved data for batch no: 1077
# Saved data for batch no: 1078
# Saved data for batch no: 1079
# Saved data for batch no: 1080
# Saved data for batch no: 1081
# Saved data for batch no: 1082
# Saved data for batch no: 1083
# Saved data for batch no: 1084
# Saved data for batch no: 1085
# Saved data for batch no: 1086
# Saved data for batch no: 1087
# Saved data for batch no: 1088
# Saved data for batch no: 1089
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Saved data for batch no: 1090
# Saved data for batch no: 1091
# Saved data for batch no: 1092
# Saved data for batch no: 1093
# Saved data for batch no: 1094
# Saved data for batch no: 1095
# Saved data for batch no: 1096
# Saved data for batch no: 1097
# Saved data for batch no: 1098
# Saved data for batch no: 1099
# Saved data for batch no: 1100
# Saved data for batch no: 1101
# Saved data for batch no: 1102
# Saved data for batch no: 1103
# Saved data for batch no: 1104
# Saved data for batch no: 1105
# Saved data for batch no: 1106
# Saved data for batch no: 1107
# Saved data for batch no: 1108
# Saved data for batch no: 1109
# Saved data for batch no: 1110
# Saved data for batch no: 1111
# Saved data for batch no: 1112
# Saved data for batch no: 1113
# Saved data for batch no: 1114
# Saved data for batch no: 1115
# Saved data for batch no: 1116
# Saved data for batch no: 1117
# Saved data for batch no: 1118
# Saved data for batch no: 1119
# Saved data for batch no: 1120
# Saved data for batch no: 1121
# Saved data for batch no: 1122
# Saved data for batch no: 1123
# Saved data for batch no: 1124
# Saved data for batch no: 1125
# Saved data for batch no: 1126
# Saved data for batch no: 1127
# Saved data for batch no: 1128
# Saved data for batch no: 1129
# Saved data for batch no: 1130
# Saved data for batch no: 1131
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Saved data for batch no: 1132
# Saved data for batch no: 1133
# Saved data for batch no: 1134
# Saved data for batch no: 1135
# Saved data for batch no: 1136
# Saved data for batch no: 1137
# Saved data for batch no: 1138
# Saved data for batch no: 1139
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Saved data for batch no: 1140
# Saved data for batch no: 1141
# Saved data for batch no: 1142
# Saved data for batch no: 1143
# Saved data for batch no: 1144
# Saved data for batch no: 1145
# Saved data for batch no: 1146
# Saved data for batch no: 1147
# Saved data for batch no: 1148
# Saved data for batch no: 1149
# Saved data for batch no: 1150
# Saved data for batch no: 1151
# Saved data for batch no: 1152
# Saved data for batch no: 1153
# Saved data for batch no: 1154
# Saved data for batch no: 1155
# Saved data for batch no: 1156
# Saved data for batch no: 1157
# Saved data for batch no: 1158
# Saved data for batch no: 1159
# Saved data for batch no: 1160
# Saved data for batch no: 1161
# Saved data for batch no: 1162
# Saved data for batch no: 1163
# Saved data for batch no: 1164
# Saved data for batch no: 1165
# Saved data for batch no: 1166
# Saved data for batch no: 1167
# Saved data for batch no: 1168
# Saved data for batch no: 1169
# Saved data for batch no: 1170
# Saved data for batch no: 1171
# Saved data for batch no: 1172
# Saved data for batch no: 1173
# Saved data for batch no: 1174
# Saved data for batch no: 1175
# Saved data for batch no: 1176
# Saved data for batch no: 1177
# Saved data for batch no: 1178
# Saved data for batch no: 1179
# Saved data for batch no: 1180
# Saved data for batch no: 1181
# Saved data for batch no: 1182
# Saved data for batch no: 1183
# Saved data for batch no: 1184
# Saved data for batch no: 1185
# Saved data for batch no: 1186
# Saved data for batch no: 1187
# Saved data for batch no: 1188
# Saved data for batch no: 1189
# Saved data for batch no: 1190
# Saved data for batch no: 1191
# Saved data for batch no: 1192
# Saved data for batch no: 1193
# Saved data for batch no: 1194
# Saved data for batch no: 1195
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Saved data for batch no: 1196
# Saved data for batch no: 1197
# Saved data for batch no: 1198
# Saved data for batch no: 1199
# Saved data for batch no: 1200
# Saved data for batch no: 1201
# Saved data for batch no: 1202
# Saved data for batch no: 1203
# Saved data for batch no: 1204
# Saved data for batch no: 1205
# Saved data for batch no: 1206
# Saved data for batch no: 1207
# Saved data for batch no: 1208
# Saved data for batch no: 1209
# Saved data for batch no: 1210
# Saved data for batch no: 1211
# Saved data for batch no: 1212
# Saved data for batch no: 1213
# Saved data for batch no: 1214
# Saved data for batch no: 1215
# Saved data for batch no: 1216
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Saved data for batch no: 1217
# Saved data for batch no: 1218
# Saved data for batch no: 1219
# Saved data for batch no: 1220
# Saved data for batch no: 1221
# Saved data for batch no: 1222
# Saved data for batch no: 1223
# Saved data for batch no: 1224
# Saved data for batch no: 1225
# Saved data for batch no: 1226
# Saved data for batch no: 1227
# Saved data for batch no: 1228
# Saved data for batch no: 1229
# Saved data for batch no: 1230
# Saved data for batch no: 1231
# Saved data for batch no: 1232
# Saved data for batch no: 1233
# Saved data for batch no: 1234
# Saved data for batch no: 1235
# Saved data for batch no: 1236
# Saved data for batch no: 1237
# Saved data for batch no: 1238
# Saved data for batch no: 1239
# Saved data for batch no: 1240
# Saved data for batch no: 1241
# Saved data for batch no: 1242
# Saved data for batch no: 1243
# Saved data for batch no: 1244
# Saved data for batch no: 1245
# Saved data for batch no: 1246
# Saved data for batch no: 1247
# Saved data for batch no: 1248
# Saved data for batch no: 1249
# Saved data for batch no: 1250
# Saved data for batch no: 1251
# Saved data for batch no: 1252
# Saved data for batch no: 1253
# Saved data for batch no: 1254
# Saved data for batch no: 1255
# Saved data for batch no: 1256
# Saved data for batch no: 1257
# Saved data for batch no: 1258
# Saved data for batch no: 1259
# Saved data for batch no: 1260
# Saved data for batch no: 1261
# Saved data for batch no: 1262
# Saved data for batch no: 1263
# Saved data for batch no: 1264
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Saved data for batch no: 1265
# Saved data for batch no: 1266
# Saved data for batch no: 1267
# Saved data for batch no: 1268
# Saved data for batch no: 1269
# Saved data for batch no: 1270
# Saved data for batch no: 1271
# Saved data for batch no: 1272
# Saved data for batch no: 1273
# Saved data for batch no: 1274
# Saved data for batch no: 1275
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Saved data for batch no: 1276
# Saved data for batch no: 1277
# Saved data for batch no: 1278
# Saved data for batch no: 1279
# Saved data for batch no: 1280
# Saved data for batch no: 1281
# Saved data for batch no: 1282
# Saved data for batch no: 1283
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Saved data for batch no: 1284
# Saved data for batch no: 1285
# Saved data for batch no: 1286
# Saved data for batch no: 1287
# Saved data for batch no: 1288
# Saved data for batch no: 1289
# Saved data for batch no: 1290
# Saved data for batch no: 1291
# Saved data for batch no: 1292
# Saved data for batch no: 1293
# Saved data for batch no: 1294
# Saved data for batch no: 1295
# Saved data for batch no: 1296
# Saved data for batch no: 1297
# Saved data for batch no: 1298
# Saved data for batch no: 1299
# Saved data for batch no: 1300
# Saved data for batch no: 1301
# Saved data for batch no: 1302
# Saved data for batch no: 1303
# Saved data for batch no: 1304
# Saved data for batch no: 1305
# Saved data for batch no: 1306
# Saved data for batch no: 1307
# Saved data for batch no: 1308
# Saved data for batch no: 1309
# Saved data for batch no: 1310
# Saved data for batch no: 1311
# Saved data for batch no: 1312
# Saved data for batch no: 1313
# Saved data for batch no: 1314
# Saved data for batch no: 1315
# Saved data for batch no: 1316
# Saved data for batch no: 1317
# Saved data for batch no: 1318
# Saved data for batch no: 1319
# Saved data for batch no: 1320
# Saved data for batch no: 1321
# Saved data for batch no: 1322
# Saved data for batch no: 1323
# Saved data for batch no: 1324
# Saved data for batch no: 1325
# ...
# Saved data for batch no: 1801
# Saved data for batch no: 1802
# Saved data for batch no: 1803
# Saved data for batch no: 1804
# Saved data for batch no: 1805
# Saved data for batch no: 1806
# Saved data for batch no: 1807
# Saved data for batch no: 1808
# Saved data for batch no: 1809
# Saved data for batch no: 1810
# Saved data for batch no: 1811
# Saved data for batch no: 1812
# Saved data for batch no: 1813
# Saved data for batch no: 1814
# Saved data for batch no: 1815
# Saved data for batch no: 1816
# Saved data for batch no: 1817
# Saved data for batch no: 1818
# Saved data for batch no: 1819
# Saved data for batch no: 1820
# Saved data for batch no: 1821
# Saved data for batch no: 1822
# Saved data for batch no: 1823
# Saved data for batch no: 1824
# Saved data for batch no: 1825
# Saved data for batch no: 1826
# Saved data for batch no: 1827
# Saved data for batch no: 1828
# Saved data for batch no: 1829
# Saved data for batch no: 1830
# Saved data for batch no: 1831
# Saved data for batch no: 1832
# Saved data for batch no: 1833
# Saved data for batch no: 1834
# Saved data for batch no: 1835
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Saved data for batch no: 1836
# Saved data for batch no: 1837
# Saved data for batch no: 1838
# Saved data for batch no: 1839
# Saved data for batch no: 1840
# Saved data for batch no: 1841
# Saved data for batch no: 1842
# Saved data for batch no: 1843
# Saved data for batch no: 1844
# Saved data for batch no: 1845
# Saved data for batch no: 1846
# Saved data for batch no: 1847
# Saved data for batch no: 1848
# Saved data for batch no: 1849
# Saved data for batch no: 1850
# Saved data for batch no: 1851
# Saved data for batch no: 1852
# Saved data for batch no: 1853
# Saved data for batch no: 1854
# Saved data for batch no: 1855
# Saved data for batch no: 1856
# Saved data for batch no: 1857
# Saved data for batch no: 1858
# Saved data for batch no: 1859
# Saved data for batch no: 1860
# Saved data for batch no: 1861
# Saved data for batch no: 1862
# Saved data for batch no: 1863
# Saved data for batch no: 1864
# Saved data for batch no: 1865
# Saved data for batch no: 1866
# Saved data for batch no: 1867
# Saved data for batch no: 1868
# Saved data for batch no: 1869
# Saved data for batch no: 1870
# Saved data for batch no: 1871
# Saved data for batch no: 1872
# Saved data for batch no: 1873
# Saved data for batch no: 1874
# Saved data for batch no: 1875
# Saved data for batch no: 1876
# Saved data for batch no: 1877
# Saved data for batch no: 1878
# Saved data for batch no: 1879
# Saved data for batch no: 1880
# Saved data for batch no: 1881
# Saved data for batch no: 1882
# Saved data for batch no: 1883
# Saved data for batch no: 1884
# Saved data for batch no: 1885
# Saved data for batch no: 1886
# Saved data for batch no: 1887
# Saved data for batch no: 1888
# Saved data for batch no: 1889
# Saved data for batch no: 1890
# Saved data for batch no: 1891
# Saved data for batch no: 1892
# Saved data for batch no: 1893
# Saved data for batch no: 1894
# Saved data for batch no: 1895
# Saved data for batch no: 1896
# Saved data for batch no: 1897
# Saved data for batch no: 1898
# Saved data for batch no: 1899
# Saved data for batch no: 1900
# Saved data for batch no: 1901
# Saved data for batch no: 1902
# Saved data for batch no: 1903
# Saved data for batch no: 1904
# Saved data for batch no: 1905
# Saved data for batch no: 1906
# Saved data for batch no: 1907
# Saved data for batch no: 1908
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Saved data for batch no: 1909
# Saved data for batch no: 1910
# Saved data for batch no: 1911
# Saved data for batch no: 1912
# Saved data for batch no: 1913
# Saved data for batch no: 1914
# Saved data for batch no: 1915
# Saved data for batch no: 1916
# Saved data for batch no: 1917
# Saved data for batch no: 1918
# Saved data for batch no: 1919
# Saved data for batch no: 1920
# Saved data for batch no: 1921
# Saved data for batch no: 1922
# Saved data for batch no: 1923
# Saved data for batch no: 1924
# Saved data for batch no: 1925
# Saved data for batch no: 1926
# Saved data for batch no: 1927
# Saved data for batch no: 1928
# Saved data for batch no: 1929
# Saved data for batch no: 1930
# Saved data for batch no: 1931
# Saved data for batch no: 1932
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Saved data for batch no: 1933
# Saved data for batch no: 1934
# Saved data for batch no: 1935
# Saved data for batch no: 1936
# Saved data for batch no: 1937
# Saved data for batch no: 1938
# Saved data for batch no: 1939
# Saved data for batch no: 1940
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Saved data for batch no: 1941
# Saved data for batch no: 1942
# Saved data for batch no: 1943
# Saved data for batch no: 1944
# Saved data for batch no: 1945
# Saved data for batch no: 1946
# Saved data for batch no: 1947
# Saved data for batch no: 1948
# Saved data for batch no: 1949
# Saved data for batch no: 1950
# Saved data for batch no: 1951
# Saved data for batch no: 1952
# Saved data for batch no: 1953
# Saved data for batch no: 1954
# Saved data for batch no: 1955
# Saved data for batch no: 1956
# Saved data for batch no: 1957
# Saved data for batch no: 1958
# Saved data for batch no: 1959
# Saved data for batch no: 1960
# Saved data for batch no: 1961
# Saved data for batch no: 1962
# Saved data for batch no: 1963
# Saved data for batch no: 1964
# Saved data for batch no: 1965
# Saved data for batch no: 1966
# Saved data for batch no: 1967
# Saved data for batch no: 1968
# Saved data for batch no: 1969
# Saved data for batch no: 1970
# Saved data for batch no: 1971
# Saved data for batch no: 1972
# Saved data for batch no: 1973
# Saved data for batch no: 1974
# Saved data for batch no: 1975
# Saved data for batch no: 1976
# Saved data for batch no: 1977
# Saved data for batch no: 1978
# Saved data for batch no: 1979
# Saved data for batch no: 1980
# Saved data for batch no: 1981
# Saved data for batch no: 1982
# Saved data for batch no: 1983
# Saved data for batch no: 1984
# Saved data for batch no: 1985
# Saved data for batch no: 1986
# Saved data for batch no: 1987
# Saved data for batch no: 1988
# Saved data for batch no: 1989
# Saved data for batch no: 1990
# Saved data for batch no: 1991
# Saved data for batch no: 1992
# Saved data for batch no: 1993
# Saved data for batch no: 1994
# Saved data for batch no: 1995
# Saved data for batch no: 1996
# Saved data for batch no: 1997
# Saved data for batch no: 1998
# Saved data for batch no: 1999
# Saved data for batch no: 2000
# Saved data for batch no: 2001
# Saved data for batch no: 2002
# Saved data for batch no: 2003
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Saved data for batch no: 2004
# Saved data for batch no: 2005
# Saved data for batch no: 2006
# Saved data for batch no: 2007
# Saved data for batch no: 2008
# Saved data for batch no: 2009
# Saved data for batch no: 2010
# Saved data for batch no: 2011
# Saved data for batch no: 2012
# Saved data for batch no: 2013
# Saved data for batch no: 2014
# Saved data for batch no: 2015
# Saved data for batch no: 2016
# Saved data for batch no: 2017
# Saved data for batch no: 2018
# Saved data for batch no: 2019
# Saved data for batch no: 2020
# Saved data for batch no: 2021
# Saved data for batch no: 2022
# Saved data for batch no: 2023
# Saved data for batch no: 2024
# Saved data for batch no: 2025
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Saved data for batch no: 2026
# Saved data for batch no: 2027
# Saved data for batch no: 2028
# Saved data for batch no: 2029
# Saved data for batch no: 2030
# Saved data for batch no: 2031
# Saved data for batch no: 2032
# Saved data for batch no: 2033
# Saved data for batch no: 2034
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Saved data for batch no: 2035
# Saved data for batch no: 2036
# Saved data for batch no: 2037
# Saved data for batch no: 2038
# Saved data for batch no: 2039
# Saved data for batch no: 2040
# Saved data for batch no: 2041
# Saved data for batch no: 2042
# Saved data for batch no: 2043
# Saved data for batch no: 2044
# Saved data for batch no: 2045
# Saved data for batch no: 2046
# Saved data for batch no: 2047
# Saved data for batch no: 2048
# Saved data for batch no: 2049
# Saved data for batch no: 2050
# Saved data for batch no: 2051
# Saved data for batch no: 2052
# Saved data for batch no: 2053
# Saved data for batch no: 2054
# Saved data for batch no: 2055
# Saved data for batch no: 2056
# Saved data for batch no: 2057
# Saved data for batch no: 2058
# Saved data for batch no: 2059
# Saved data for batch no: 2060
# Saved data for batch no: 2061
# Saved data for batch no: 2062
# Saved data for batch no: 2063
# Saved data for batch no: 2064
# Saved data for batch no: 2065
# Saved data for batch no: 2066
# Saved data for batch no: 2067
# Saved data for batch no: 2068
# Saved data for batch no: 2069
# Saved data for batch no: 2070
# Saved data for batch no: 2071
# Saved data for batch no: 2072
# Saved data for batch no: 2073
# Saved data for batch no: 2074
# Saved data for batch no: 2075
# Saved data for batch no: 2076
# Saved data for batch no: 2077
# Saved data for batch no: 2078
# Saved data for batch no: 2079
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Saved data for batch no: 2080
# Saved data for batch no: 2081
# Saved data for batch no: 2082
# Saved data for batch no: 2083
# Saved data for batch no: 2084
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Unsupported number of image dimensions: 2
# Saved data for batch no: 2085
# Saved data for batch no: 2086
# Saved data for batch no: 2087
# Saved data for batch no: 2088
# Saved data for batch no: 2089
# Saved data for batch no: 2090
# Saved data for batch no: 2091
# Saved data for batch no: 2092
# Saved data for batch no: 2093
# Saved data for batch no: 2094
# Saved data for batch no: 2095
# Saved data for batch no: 2096
# Saved data for batch no: 2097
# Saved data for batch no: 2098
# Saved data for batch no: 2099
# Saved data for batch no: 2100
# Saved data for batch no: 2101
# Saved data for batch no: 2102
# Saved data for batch no: 2103
# Saved data for batch no: 2104
# Saved data for batch no: 2105
# Saved data for batch no: 2106
# Saved data for batch no: 2107
# Saved data for batch no: 2108
# Saved data for batch no: 2109
# Saved data for batch no: 2110
# Saved data for batch no: 2111
# Saved data for batch no: 2112
# Saved data for batch no: 2113
# Saved data for batch no: 2114
# Saved data for batch no: 2115
# Saved data for batch no: 2116
# Saved data for batch no: 2117
# Saved data for batch no: 2118
# Saved data for batch no: 2119
# Saved data for batch no: 2120
# Saved data for batch no: 2121
# Saved data for batch no: 2122
# Saved data for batch no: 2123
# Saved data for batch no: 2124
# Saved data for batch no: 2125
# Saved data for batch no: 2126
# Saved data for batch no: 2127
# Saved data for batch no: 2128
# Saved data for batch no: 2129
# Saved data for batch no: 2130
# Saved data for batch no: 2131
# Saved data for batch no: 2132
# Saved data for batch no: 2133
# Saved data for batch no: 2134
# Saved data for batch no: 2135
# Saved data for batch no: 2136
# Saved data for batch no: 2137
# Saved data for batch no: 2138
# Saved data for batch no: 2139
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 logits, labels = prediction(model, processor, validation_dataset, device)
#
# TypeError: cannot unpack non-iterable NoneType object

# %% [markdown]
# ### Logits and labels have been store in .pt file for calibration methods

# %% [markdown]
#  Path : /teamspace/studios/this_studio/Selective_Prediction_VQA/predictions/logits_and_labels/Logits_and_labels0.pt
